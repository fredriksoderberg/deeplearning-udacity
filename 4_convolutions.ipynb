# %% [markdown]
# Deep Learning
# =============
#
# Assignment 4
# ------------
#
# Previously in `2_fullyconnected.ipynb` and `3_regularization.ipynb`, we trained fully connected networks to classify [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) characters.
#
# The goal of this assignment is make the neural network convolutional.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
# - convolutions need the image data formatted as a cube (width by height by #channels)
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 2.900596
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 1.720474
# Minibatch accuracy: 31.2%
# Validation accuracy: 49.0%
# Minibatch loss at step 100: 1.233881
# Minibatch accuracy: 50.0%
# Validation accuracy: 69.9%
# Minibatch loss at step 150: 0.700726
# Minibatch accuracy: 81.2%
# Validation accuracy: 75.4%
# Minibatch loss at step 200: 0.823433
# Minibatch accuracy: 75.0%
# Validation accuracy: 77.6%
# Minibatch loss at step 250: 1.203671
# Minibatch accuracy: 62.5%
# Validation accuracy: 77.6%
# Minibatch loss at step 300: 0.668661
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.0%
# Minibatch loss at step 350: 0.246033
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.5%
# Minibatch loss at step 400: 0.288460
# Minibatch accuracy: 100.0%
# Validation accuracy: 80.5%
# Minibatch loss at step 450: 0.627117
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.0%
# Minibatch loss at step 500: 0.633965
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.1%
# Minibatch loss at step 550: 0.601537
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.0%
# Minibatch loss at step 600: 0.264723
# Minibatch accuracy: 93.8%
# Validation accuracy: 81.1%
# Minibatch loss at step 650: 0.810747
# Minibatch accuracy: 68.8%
# Validation accuracy: 82.0%
# Minibatch loss at step 700: 1.069661
# Minibatch accuracy: 62.5%
# Validation accuracy: 81.9%
# Minibatch loss at step 750: 0.625419
# Minibatch accuracy: 68.8%
# Validation accuracy: 82.2%
# Minibatch loss at step 800: 0.460754
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.6%
# Minibatch loss at step 850: 0.878671
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.4%
# Minibatch loss at step 900: 1.069386
# Minibatch accuracy: 68.8%
# Validation accuracy: 82.7%
# Minibatch loss at step 950: 0.898325
# Minibatch accuracy: 68.8%
# Validation accuracy: 82.3%
# Minibatch loss at step 1000: 0.285406
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.2%
# Test accuracy: 89.2%

# %% [markdown]
# ---
# Problem 1
# ---------
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides by a max pooling operation (`nn.max_pool()`) of stride 2 and kernel size 2.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # New Model.
  def model(data):
    #conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
    conv = tf.nn.max_pool(data, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME', data_format='NHWC')
    hidden = tf.nn.relu(conv + layer1_biases)
    #conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
    conv = tf.nn.max_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME', data_format='NHWC')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 4.292758
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 2.307472
# Minibatch accuracy: 0.0%
# Validation accuracy: 10.0%
# Minibatch loss at step 100: 2.301582
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 150: 2.302647
# Minibatch accuracy: 0.0%
# Validation accuracy: 10.0%
# Minibatch loss at step 200: 2.305558
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 250: 2.300207
# Minibatch accuracy: 0.0%
# Validation accuracy: 10.4%
# Minibatch loss at step 300: 2.303694
# Minibatch accuracy: 6.2%
# Validation accuracy: 14.6%
# Minibatch loss at step 350: 2.294072
# Minibatch accuracy: 0.0%
# Validation accuracy: 10.0%
# Minibatch loss at step 400: 2.276659
# Minibatch accuracy: 0.0%
# Validation accuracy: 11.8%
# Minibatch loss at step 450: 2.110766
# Minibatch accuracy: 37.5%
# Validation accuracy: 13.4%
# Minibatch loss at step 500: 2.321972
# Minibatch accuracy: 0.0%
# Validation accuracy: 19.5%
# Minibatch loss at step 550: 2.240275
# Minibatch accuracy: 6.2%
# Validation accuracy: 21.9%
# Minibatch loss at step 600: 2.158545
# Minibatch accuracy: 25.0%
# Validation accuracy: 13.4%
# Minibatch loss at step 650: 2.418842
# Minibatch accuracy: 12.5%
# Validation accuracy: 18.9%
# Minibatch loss at step 700: 2.277709
# Minibatch accuracy: 12.5%
# Validation accuracy: 20.2%
# Minibatch loss at step 750: 2.326008
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 800: 2.062376
# Minibatch accuracy: 18.8%
# Validation accuracy: 19.5%
# Minibatch loss at step 850: 2.118315
# Minibatch accuracy: 18.8%
# Validation accuracy: 22.3%
# Minibatch loss at step 900: 2.100062
# Minibatch accuracy: 25.0%
# Validation accuracy: 28.1%
# Minibatch loss at step 950: 2.179046
# Minibatch accuracy: 12.5%
# Validation accuracy: 24.8%
# Minibatch loss at step 1000: 2.070976
# Minibatch accuracy: 18.8%
# Validation accuracy: 32.9%
# Test accuracy: 36.2%

# %% [markdown]
# ---
# Problem 2
# ---------
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic [LeNet5](http://yann.lecun.com/exdb/lenet/) architecture, adding Dropout, and/or adding learning rate decay.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64
num_hidden2 = 32

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_hidden2], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden2]))
  layer5_weights = tf.Variable(tf.truncated_normal(
      [num_hidden2, num_labels], stddev=0.1))
  layer5_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  dropout_prob = tf.placeholder("float")
  
  
  # New Model.
  def model(data):
    #conv1
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    
    #pooling1
    pool1 = tf.nn.max_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME', name='pool1')
    norm1 = tf.nn.lrn(pool1, 4, bias=1.0, alpha=0.001 / 9.0, beta=0.75, name='norm1')
    
    #conv2
    conv = tf.nn.conv2d(norm1, layer2_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    
    #pooling2
    pool2 = tf.nn.max_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME', name='pool2')
    norm2 = tf.nn.lrn(pool2, 4, bias=1.0, alpha=0.001 / 9.0, beta=0.75, name='norm1')
    
    #conv3 
    conv = tf.nn.conv2d(norm2, layer2_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    hidden = tf.matmul(hidden, layer4_weights) + layer4_biases
    
    #dropout
    hidden = tf.nn.dropout(hidden, dropout_prob)
    
    return tf.matmul(hidden, layer5_weights) + layer5_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Learning rate decay
  global_step = tf.Variable(0, trainable=False)
  starter_learning_rate = 0.001
  learning_rate = tf.train.exponential_decay(starter_learning_rate, global_step, 100000, 0.96, staircase=True)
    
  # Optimizer  
  optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels, dropout_prob:0.5}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 1000 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(session=session,feed_dict={dropout_prob:1.0}), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(session=session,feed_dict={dropout_prob:1.0}), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.108175
# Minibatch accuracy: 18.8%
# Validation accuracy: 7.3%
# Minibatch loss at step 1000: 1.821372
# Minibatch accuracy: 37.5%
# Validation accuracy: 46.0%
# Minibatch loss at step 2000: 1.411295
# Minibatch accuracy: 56.2%
# Validation accuracy: 72.3%
# Minibatch loss at step 3000: 1.167996
# Minibatch accuracy: 56.2%
# Validation accuracy: 77.4%
# Minibatch loss at step 4000: 1.023606
# Minibatch accuracy: 62.5%
# Validation accuracy: 79.2%
# Minibatch loss at step 5000: 1.329581
# Minibatch accuracy: 62.5%
# Validation accuracy: 80.0%
# Minibatch loss at step 6000: 0.468480
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.9%
# Minibatch loss at step 7000: 0.653989
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.7%
# Minibatch loss at step 8000: 0.592189
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.2%
# Minibatch loss at step 9000: 0.332430
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.3%
# Minibatch loss at step 10000: 1.740836
# Minibatch accuracy: 62.5%
# Validation accuracy: 82.5%
# Minibatch loss at step 11000: 0.863506
# Minibatch accuracy: 68.8%
# Validation accuracy: 82.9%
# Minibatch loss at step 12000: 0.979765
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.4%
# Minibatch loss at step 13000: 0.519321
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.4%
# Minibatch loss at step 14000: 0.496416
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.1%
# Minibatch loss at step 15000: 0.662611
# Minibatch accuracy: 68.8%
# Validation accuracy: 84.0%
# Minibatch loss at step 16000: 0.756141
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.8%
# Minibatch loss at step 17000: 0.400433
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.5%
# Minibatch loss at step 18000: 0.924707
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.2%
# Minibatch loss at step 19000: 0.754364
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.7%
# Minibatch loss at step 20000: 0.451348
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.6%
# Minibatch loss at step 21000: 0.471196
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.2%
# Minibatch loss at step 22000: 0.679279
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.9%
# Minibatch loss at step 23000: 0.314472
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.1%
# Minibatch loss at step 24000: 0.754579
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.4%
# Minibatch loss at step 25000: 0.942158
# Minibatch accuracy: 68.8%
# Validation accuracy: 85.3%
# Minibatch loss at step 26000: 0.482000
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.6%
# Minibatch loss at step 27000: 0.696341
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.7%
# Minibatch loss at step 28000: 0.604308
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.9%
# Minibatch loss at step 29000: 0.235202
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.0%
# Minibatch loss at step 30000: 0.631682
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.1%
# Minibatch loss at step 31000: 0.844694
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.8%
# Minibatch loss at step 32000: 0.832119
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.1%
# Minibatch loss at step 33000: 0.590145
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.2%
# Minibatch loss at step 34000: 0.469523
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.5%
# Minibatch loss at step 35000: 0.221828
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.5%
# Minibatch loss at step 36000: 0.732011
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.6%
# Minibatch loss at step 37000: 0.265755
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.7%
# Minibatch loss at step 38000: 0.740582
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.5%
# Minibatch loss at step 39000: 0.396151
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.7%
# Minibatch loss at step 40000: 0.910609
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.9%
# Minibatch loss at step 41000: 0.348624
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.7%
# Minibatch loss at step 42000: 0.405505
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.1%
# Minibatch loss at step 43000: 0.276066
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.9%
# Minibatch loss at step 44000: 0.133117
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.0%
# Minibatch loss at step 45000: 0.240308
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.9%
# Minibatch loss at step 46000: 0.498248
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.0%
# Minibatch loss at step 47000: 0.611812
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.0%
# Minibatch loss at step 48000: 0.428027
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.1%
# Minibatch loss at step 49000: 0.141767
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.2%
# Minibatch loss at step 50000: 0.252652
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.1%
# Minibatch loss at step 51000: 0.193338
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.2%
# Minibatch loss at step 52000: 0.384494
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.4%
# Minibatch loss at step 53000: 1.538114
# Minibatch accuracy: 62.5%
# Validation accuracy: 87.5%
# Minibatch loss at step 54000: 0.152254
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.7%
# Minibatch loss at step 55000: 0.728512
# Minibatch accuracy: 68.8%
# Validation accuracy: 87.6%
# Minibatch loss at step 56000: 0.309599
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.2%
# Minibatch loss at step 57000: 0.401873
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.6%
# Minibatch loss at step 58000: 0.208536
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.5%
# Minibatch loss at step 59000: 0.429276
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.7%
# Minibatch loss at step 60000: 0.436237
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.8%
# Minibatch loss at step 61000: 0.484012
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.6%
# Minibatch loss at step 62000: 0.537922
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.8%
# Minibatch loss at step 63000: 0.236203
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.7%
# Minibatch loss at step 64000: 0.503340
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.2%
# Minibatch loss at step 65000: 0.339262
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.8%
# Minibatch loss at step 66000: 0.815822
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.0%
# Minibatch loss at step 67000: 0.350695
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.0%
# Minibatch loss at step 68000: 0.096972
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.0%
# Minibatch loss at step 69000: 0.139847
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.7%
# Minibatch loss at step 70000: 0.490147
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.8%
# Minibatch loss at step 71000: 0.224009
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.1%
# Minibatch loss at step 72000: 0.189136
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.9%
# Minibatch loss at step 73000: 0.111791
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.2%
# Minibatch loss at step 74000: 0.313283
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.0%
# Minibatch loss at step 75000: 0.738910
# Minibatch accuracy: 75.0%
# Validation accuracy: 88.0%
# Minibatch loss at step 76000: 0.404830
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.1%
# Minibatch loss at step 77000: 0.236666
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.1%
# Minibatch loss at step 78000: 0.061566
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.3%
# Minibatch loss at step 79000: 0.231795
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.3%
# Minibatch loss at step 80000: 0.245855
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.2%
# Minibatch loss at step 81000: 0.855709
# Minibatch accuracy: 68.8%
# Validation accuracy: 88.2%
# Minibatch loss at step 82000: 0.696478
# Minibatch accuracy: 75.0%
# Validation accuracy: 88.1%
# Minibatch loss at step 83000: 0.735375
# Minibatch accuracy: 75.0%
# Validation accuracy: 88.2%
# Minibatch loss at step 84000: 0.236004
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.3%
# Minibatch loss at step 85000: 0.409497
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.5%
# Minibatch loss at step 86000: 0.422477
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.2%
# Minibatch loss at step 87000: 0.102590
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.3%
# Minibatch loss at step 88000: 0.353001
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.1%
# Minibatch loss at step 89000: 0.149728
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.3%
# Minibatch loss at step 90000: 0.563375
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.5%
# Minibatch loss at step 91000: 0.339085
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.4%
# Minibatch loss at step 92000: 0.316317
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.5%
# Minibatch loss at step 93000: 0.270967
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.5%
# Minibatch loss at step 94000: 0.246848
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.5%
# Minibatch loss at step 95000: 0.300667
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.2%
# Minibatch loss at step 96000: 0.562910
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.5%
# Minibatch loss at step 97000: 0.070561
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.6%
# Minibatch loss at step 98000: 0.754741
# Minibatch accuracy: 75.0%
# Validation accuracy: 88.6%
# Minibatch loss at step 99000: 0.212050
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.7%
# Minibatch loss at step 100000: 0.063656
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.5%
# Test accuracy: 94.3%
